# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Importing dfs

# %%
path = r"C:\Users\dioog\02. Bloomberg Analysis"

# %%
print(path)
# Out:
# C:\Users\dioog\02. Bloomberg Analysis

# %%
df_orig = pd.read_csv(os.path.join(path, "02_Data", "Original data", "dataset_26nov.csv"))

# %% [markdown]
# ### Exploring the data

# %%
df_orig.head()
# Out:
#              Ticker        Short Name    Market Cap  Rank(Current Market Cap)  \
# 0    AAPL US Equity         APPLE INC  2.045317e+12                       1.0
# 1  ARAMCO AB Equity  SAUDI ARABIAN OI  1.887799e+12                       2.0
# 2    MSFT US Equity    MICROSOFT CORP  1.642367e+12                       3.0
# 3    AMZN US Equity    AMAZON.COM INC  1.571013e+12                       4.0
# 4   GOOGL US Equity    ALPHABET INC-A  1.202594e+12                       5.0
#
#            Sector  Prim Exch Nm        Country Cntry of Incorp  \
# 0      Technology     NASDAQ GS  UNITED STATES              US
# 1          Energy  Saudi Arabia   SAUDI ARABIA              SA
# 2      Technology     NASDAQ GS  UNITED STATES              US
# 3  Communications     NASDAQ GS  UNITED STATES              US
# 4  Communications     NASDAQ GS  UNITED STATES              US
#
#    Best Analyst Rating  52Wk High  ...  03/02/2020 02/03/2020 01/04/2020  \
# ...

# %%
df_orig.tail()
# Out:
#                 Ticker        Short Name    Market Cap  \
# 4932    1357 JP Equity  NOMU-NE 225 INVS  2.757690e+09
# 4933    SCHC US Equity  SCHWAB INTL SMAL  2.755676e+09
# 4934    SPMB US Equity  SPDR PORT MTGE B  2.755527e+09
# 4935    VNLA US Equity   JANUS HENDERSON  2.752932e+09
# 4936  011790 KS Equity        SKC CO LTD  2.751337e+09
#
#       Rank(Current Market Cap)      Sector Prim Exch Nm        Country  \
# 4932                    4994.0       Funds        Tokyo          JAPAN
# 4933                    4996.0       Funds    NYSE Arca  UNITED STATES
# 4934                    4997.0       Funds    NYSE Arca  UNITED STATES
# 4935                    4998.0       Funds    NYSE Arca  UNITED STATES
# 4936                    4999.0  Industrial     Korea SE    SOUTH KOREA
#
#      Cntry of Incorp  Best Analyst Rating  52Wk High  ...  03/02/2020  \
# 4932              JP             0.000000      16.05  ...        8.51
# ...

# %%
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4937 entries, 0 to 4936
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Ticker                    4937 non-null   object
#  1   Short Name                4937 non-null   object
#  2   Market Cap                4937 non-null   float64
#  3   Rank(Current Market Cap)  4937 non-null   float64
#  4   Sector                    4937 non-null   object
#  5   Prim Exch Nm              4937 non-null   object
#  6   Country                   4937 non-null   object
#  7   Cntry of Incorp           4937 non-null   object
#  8   Best Analyst Rating       4824 non-null   float64
#  9   52Wk High                 4937 non-null   float64
#  10  52Wk Low                  4937 non-null   float64
#  11  52Wk Low Dt               4937 non-null   object
#  12  52Wk High Dt              4937 non-null   object
# ...

# %%
df_orig.shape
# Out:
# (4937, 26)

# %%
df_orig.describe()
# Out:
#          Market Cap  Rank(Current Market Cap)  Best Analyst Rating  \
# count  4.937000e+03               4937.000000          4824.000000
# mean   1.912620e+10               2477.893660             3.672289
# std    6.586437e+10               1434.490523             1.337234
# min    2.751337e+09                  1.000000             0.000000
# 25%    4.071396e+09               1236.000000             3.363636
# 50%    6.752808e+09               2474.000000             4.052631
# 75%    1.494602e+10               3714.000000             4.556666
# max    2.045317e+12               4999.000000             5.000000
#
#            52Wk High       52Wk Low  1Y Tot Ret (%)     02/12/2019  \
# count    4937.000000    4937.000000     4937.000000    4937.000000
# mean      187.105252     110.744805       26.113857     157.924908
# std      5176.619658    3546.204029       93.391530    4870.501376
# min         0.000000       0.000000      -77.790000       0.000000
# ...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Mixed-Type Data

# %%
# finding mixed-type columns within dataframe
for col in df_orig.columns.tolist():
  weird = (df_orig[[col]].applymap(type) != df_orig[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_orig[weird]) > 0:
    print (col)

# %% [markdown]
# ### Missing Values

# %%
# finding missing values within dataframe
df_orig.isnull().sum()
# Out:
# Ticker                        0
# Short Name                    0
# Market Cap                    0
# Rank(Current Market Cap)      0
# Sector                        0
# Prim Exch Nm                  0
# Country                       0
# Cntry of Incorp               0
# Best Analyst Rating         113
# 52Wk High                     0
# 52Wk Low                      0
# 52Wk Low Dt                   0
# 52Wk High Dt                  0
# 1Y Tot Ret (%)                0
# 02/12/2019                    0
# 01/01/2020                    0
# 03/02/2020                    0
# 02/03/2020                    0
# 01/04/2020                    0
# 01/05/2020                    0
# 01/06/2020                    0
# 01/07/2020                    0
# 03/08/2020                    0
# 01/09/2020                    0
# 01/10/2020                    0
# 02/11/2020                    0
# dtype: int64

# %%
len(df_orig[df_orig["Best Analyst Rating"] == 0])
# Out:
# 430

# %%
# The column "Best Analyst Rating" has 113 missing values. This is not enough to exclude it. Imputation is not an option. 
# If necessary, in a later analysis stage, I could create a new variable that acts like a flag based on the missing value.

# %% [markdown]
# ### Duplicates

# %%
# finding duplicates

df_dups = df_orig[df_orig.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Ticker, Short Name, Market Cap, Rank(Current Market Cap), Sector, Prim Exch Nm, Country, Cntry of Incorp, Best Analyst Rating, 52Wk High, 52Wk Low, 52Wk Low Dt, 52Wk High Dt, 1Y Tot Ret (%), 02/12/2019, 01/01/2020, 03/02/2020, 02/03/2020, 01/04/2020, 01/05/2020, 01/06/2020, 01/07/2020, 03/08/2020, 01/09/2020, 01/10/2020, 02/11/2020]
# Index: []
#
# [0 rows x 26 columns]

# %%
# no duplicates found

# %% [markdown]
# ### Exporting data

# %%
df_orig.to_csv(os.path.join(path, "02_Data", "Prepared data", "df_orig_checked.csv"))
